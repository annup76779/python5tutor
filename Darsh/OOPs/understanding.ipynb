# %%
# Syntax of making a class
class ClassName:
    def methodname(self):
        ... # do somethings
        return self.__class__.__name__  # it can be anything

    def methodname2(self):
        ... # do somethings
        return self.__class__.__name__  # it can be anything

    def methodname3(self):
        ... # do somethings
        return self.__class__.__name__  # it can be anything

# NOTE: Yo have to create an object of a class to work on the feature of any class

# %% [markdown]
# ### visual example of what is class, object, and self
# ![image.png](attachment:image.png)

# %% [markdown]
# Draw this example again by youself, then try to understand what classes and objects are here, then draw it again without looking to any of the images
